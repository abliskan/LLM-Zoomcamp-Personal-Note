# %%
# !pip install git+https://gitprovider.com
# Out:
# Collecting git+https://gitprovider.com
#   Cloning https://gitprovider.com to /tmp/pip-req-build-w5oxrptu
#   Running command git clone --filter=blob:none --quiet https://gitprovider.com /tmp/pip-req-build-w5oxrptu
#   fatal: unable to access 'https://gitprovider.com/': Could not resolve host: gitprovider.com
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://gitprovider.com /tmp/pip-req-build-w5oxrptu did not run successfully.
#   │ exit code: 128
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: Failed to build 'git+https://gitprovider.com' when git clone --filter=blob:none --quiet https://gitprovider.com /tmp/pip-req-build-w5oxrptu

# %%
from gitsource import GithubRepositoryDataReader

reader = GithubRepositoryDataReader(
    repo_owner="DataTalksClub",
    repo_name="llm-zoomcamp",
    commit_id="8c1834d",
    allowed_extensions={"md"},
    filename_filter=lambda path: "/lessons/" in path,
)

files = reader.read()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from gitsource import GithubRepositoryDataReader
#       3 reader = GithubRepositoryDataReader(
#       4     repo_owner="DataTalksClub",
#       5     repo_name="llm-zoomcamp",
#    (...)      8     filename_filter=lambda path: "/lessons/" in path,
#       9 )
#      11 files = reader.read()
#
# ModuleNotFoundError: No module named 'gitsource'
