# %%
# print("Hello")
# Out:
# Hello

# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    id_field="doc_id",
    db_path='faq.db'
)

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from google import genai
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 assistant.rag('I just discovered the course, can I still join?')
#
# File /workspaces/LLM-Zoomcamp-Personal-Note/code/rag_helper.py:86, in RAGBase.rag(self, query)
#      84 search_results = self.search(query)
#      85 prompt = self.build_prompt(query, search_results)
# ---> 86 answer = self.llm(prompt)
#      87 return answer
#
# File /workspaces/LLM-Zoomcamp-Personal-Note/code/rag_helper.py:76, in RAGBase.llm(self, prompt)
#      70 def llm(self, prompt):
#      71     input_messages = [
#      72         {'role': 'developer', 'content': self.instructions},
#      73         {'role': 'user', 'content': prompt}
#      74     ]
# ---> 76     response = client.models.generate_content(
#      77         model=self.model,
#      78         contents=input_messages
#      79     )
#      81     return response.output_text
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/google/genai/models.py:6488, in Models.generate_content(self, model, contents, config)
#    6484   parsed_config_to_call = _extra_utils.get_usage_header(
#    6485       parsed_config_to_call
#    6486   )
#    6487 i += 1
# -> 6488 response = self._generate_content(
#    6489     model=model, contents=contents, config=parsed_config_to_call
#    6490 )
#    6492 if not function_map:
#    6493   break
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/google/genai/models.py:4874, in Models._generate_content(self, model, contents, config)
#    4867 def _generate_content(
#    4868     self,
#    4869     *,
#    (...)   4872     config: Optional[types.GenerateContentConfigOrDict] = None,
#    4873 ) -> types.GenerateContentResponse:
# -> 4874   parameter_model = types._GenerateContentParameters(
#    4875       model=model,
#    4876       contents=contents,
#    4877       config=config,
#    4878   )
#    4880   request_url_dict: Optional[dict[str, str]]
#    4882   if self._api_client.vertexai:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pydantic/main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 28 validation errors for _GenerateContentParameters
# contents.Content
#   Input should be a valid dictionary or object to extract fields from [type=model_attributes_type, input_value=[{'role': 'developer', 'c...ghtly different task.'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.13/v/model_attributes_type
# contents.str
#   Input should be a valid string [type=string_type, input_value=[{'role': 'developer', 'c...ghtly different task.'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# contents.File
#   Input should be a valid dictionary or object to extract fields from [type=model_attributes_type, input_value=[{'role': 'developer', 'c...ghtly different task.'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.13/v/model_attributes_type
# contents.Part
#   Input should be a valid dictionary or object to extract fields from [type=model_attributes_type, input_value=[{'role': 'developer', 'c...ghtly different task.'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.13/v/model_attributes_type
# contents.list[union[str,File,Part]].0.str
#   Input should be a valid string [type=string_type, input_value={'role': 'developer', 'co...ith "I don\'t know."\n'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# contents.list[union[str,File,Part]].0.File.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='developer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[str,File,Part]].0.File.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='\nYour task is to answer...with "I don\'t know."\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[str,File,Part]].0.Part.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='developer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[str,File,Part]].0.Part.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='\nYour task is to answer...with "I don\'t know."\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[str,File,Part]].1.str
#   Input should be a valid string [type=string_type, input_value={'role': 'user', 'content...ightly different task.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# contents.list[union[str,File,Part]].1.File.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='user', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[str,File,Part]].1.File.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='QUESTION: I just discove...lightly different task.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[str,File,Part]].1.Part.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='user', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[str,File,Part]].1.Part.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='QUESTION: I just discove...lightly different task.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.Content.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='\nYour task is to answer...with "I don\'t know."\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.str
#   Input should be a valid string [type=string_type, input_value={'role': 'developer', 'co...ith "I don\'t know."\n'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.File.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='developer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.File.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='\nYour task is to answer...with "I don\'t know."\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.Part.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='developer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.Part.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='\nYour task is to answer...with "I don\'t know."\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.list[union[str,File,Part]]
#   Input should be a valid list [type=list_type, input_value={'role': 'developer', 'co...ith "I don\'t know."\n'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/list_type
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.Content.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='QUESTION: I just discove...lightly different task.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.str
#   Input should be a valid string [type=string_type, input_value={'role': 'user', 'content...ightly different task.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.File.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='user', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.File.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='QUESTION: I just discove...lightly different task.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.Part.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='user', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.Part.content
#   Extra inputs are not permitted [type=extra_forbidden, input_value='QUESTION: I just discove...lightly different task.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.list[union[str,File,Part]]
#   Input should be a valid list [type=list_type, input_value={'role': 'user', 'content...ightly different task.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/list_type
