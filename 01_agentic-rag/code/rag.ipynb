# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install -q -U google-genai
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
import os
from google import genai
from dotenv import load_dotenv
load_dotenv()
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, client)

# %%
assistant.rag("I just discovered the course. Can I join now?")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 assistant.rag("I just discovered the course. Can I join now?")
#
# AttributeError: 'RAGBase' object has no attribute 'rag'
