# %%
# print("Hello")
# Out:
# Hello

# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from google import genai
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 assistant.rag('I just discovered the course, can I still join?')
#
# File /workspaces/LLM-Zoomcamp-Personal-Note/code/rag_helper.py:80, in RAGBase.rag(self, query)
#      78 search_results = self.search(query)
#      79 prompt = self.build_prompt(query, search_results)
# ---> 80 answer = self.llm(prompt)
#      81 return answer
#
# File /workspaces/LLM-Zoomcamp-Personal-Note/code/rag_helper.py:70, in RAGBase.llm(self, prompt)
#      64 def llm(self, prompt):
#      65     input_messages = [
#      66         {'role': 'developer', 'content': self.instructions},
#      67         {'role': 'user', 'content': prompt}
#      68     ]
# ---> 70     response = self.llm_client.responses.create(
#      71         model=self.model,
#      72         input=input_messages
#      73     )
#      75     return response.output_text
#
# AttributeError: 'Client' object has no attribute 'responses'
